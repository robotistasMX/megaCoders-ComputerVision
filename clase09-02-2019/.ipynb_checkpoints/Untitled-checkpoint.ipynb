# %% [markdown]
# # Clase 02-02-2019

# %% [markdown]
# ## Guía Alumno - @RobotistasMX

# %% [markdown]
# ### Material clase

# %% [markdown]
# https://drive.google.com/file/d/1uNQaZW1o1c3a14yT3S5t6h0V9_lg30P7/view

# %% [markdown]
# ### Importar Anaconda pywin32

# %% [markdown]
# conda install -c anaconda pywin32

# %% [markdown]
# ### Programa ejemplo teclas

# %%
import win32com.client
import cv2 
shell = win32com.client.Dispatch("WScript.Shell")

while True:
    k = cv2.waitKey(10)    
    if k == 27:
        shell.SendKeys("{UP}")

# %% [markdown]
# ### Guardar imagen con opencv

# %% [markdown]
# cv2.imwrite(write_name, frame)

# %% [markdown]
# ### Reto 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://apps.thecodepost.org/trex/trex.html

# %% [markdown]
# ##### Puntos:

# %% [markdown]
# Puntos del Reto = 200, BONUS = 100

# %% [markdown]
# ### Reto 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Puntos

# %% [markdown]
# Puntos del Reto = 300, BONUS por ronda = 30

# %% [markdown]
# ### Reto 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Puntos del Reto = 250, BONUS por ronda = 50
